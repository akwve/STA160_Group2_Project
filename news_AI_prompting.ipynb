# %%
import web_scraping_and_cleaning_functions as sc_fn
from openai import OpenAI

# %%
client = OpenAI(api_key="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")  # paste your key here


def classify_news(url):
    """
    Classify whether the given cleaned text is a true or false news article.
    Returns a deterministic output like:
    "True, confidence level = 0.97"
    """
    if not url.strip():
        return "Please enter a URL.", ""
    
    # Scrape and clean the article
    cleaned_text = sc_fn.scrape_and_clean_article(url)

    prompt = f"""
You are an AI model trained to classify whether a given news article text represents a true or false (fake) news article.

The input will be a cleaned and preprocessed text consisting of a concatenation of the article’s title and body, where the text has already been tokenized and stopwords removed.

Your task:
1. Analyze the semantic and linguistic features of the cleaned text.
2. Determine whether it is a True or False news article.
3. Provide your result strictly in the following format:
   “True, confidence level = 0.97”
   or
   “False, confidence level = 0.92”

Rules:
- Always provide a binary classification ("True" or "False").
- The confidence level must be on a 0–1 scale (e.g., 0.83).
- The same input text must always produce the same confidence value (deterministic, not random).
- Never output additional text or explanation.
- Confidence level must not be less than 0.5.
- Spend additional time reasoning internally to ensure accuracy and consistency.

Input cleaned text:
{cleaned_text}
"""

    response = client.chat.completions.create(
        model="gpt-5",  # or "gpt-4o" / "gpt-4-turbo" depending on your access
        messages=[{"role": "user", "content": prompt}]
    )

    result = response.choices[0].message.content.strip()
    return result
